# %%
df_emp = spark.read.csv(path='dbfs:/FileStore/data/empCompanyData.csv', header=True, nullValue='null')
df_dep = spark.read.csv(path='dbfs:/FileStore/spark_RealTimeScenarioData/dept.csv', header=True)
display(df_emp)
display(df_dep)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.fs.put('dbfs:/FileStore/spark_RealTimeScenarioData/dept.csv',"""Deptno,Dname,loc
10,ACCOUNTING,NEW YORK
20,RESEARCH,DALLAS
30,SALES,CHICAGO
40,OPERATIONS,BOSTON
""", True)
# Out:
# Wrote 97 bytes.
# Out[3]: True

# %%
final_df = df_emp.join(df_dep, df_emp['DEPTNO']==df_dep['Deptno'], 'inner')
display(final_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
final_df.write.format('delta').saveAsTable('emp_dept_data_csv')
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-3617822327266943> in <cell line: 1>()
# ----> 1 final_df.write.format('delta').saveAsTable('emp_dept_data_csv')
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# /databricks/spark/python/pyspark/sql/readwriter.py in saveAsTable(self, name, format, mode, partitionBy, **options)
#    1039         if format is not None:
#    1040             self.format(format)
# -> 1041         self._jwrite.saveAsTable(name)
#    1042
#    1043     def json(
#
# ...

# %%
final_df = df_emp.join(df_dep, ['DEPTNO'], 'inner')
display(final_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
final_df.write.format('delta').saveAsTable('emp_dept_data_csv')

# %%
# %sql
select * from emp_dept_data_csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
